# %% [markdown]
# # Preparación del Entorno

# %% [markdown]
# Sobre Ensambles
#
#  ---------------------------
# Step 1: Conceptos
# ---------------------------
#
#  Hay quienes pasan por el bosque y sólo ven leña para el fuego
#  - León Tolstoi
#
# Preguntas
# - ¿Qué es un ensamble de modelos?
# - ¿Cómo tienen que ser los modelos dentro de un ensamble?
# - ¿Qué técnicas conoce para ensamblar modelos?
# - ¿Por qué funcionan mejor los ensambles?
#
#
# Los ensambles pueden partir de modelos ya desarrollados, o de modelos que se creen especialmente para ser ensamblados.
#
#  Sobre los segundos, veremos son los llamados Bagging (bootstrap aggregating).
#  - Hacer **N** nuevos conjunto de entrenamiento usando boostraping, o sea,
#    reemplazar nuestro dataset por elementos aleatorios con reemplazo.
#  - Para este cada nuevo dataset obtener un modelo.
#  - Promediar (o votar) las salidas de los modelos.
#
# El espíritu detrás de este algoritmo, puede entenderse en que cada modelo es una especialista de sólo una parte, y la suma de muchos especialistas consiguen un buen modelo.
#
# - El algoritmo de **bagging** más conocido es el **random fore

# %% [markdown]
# ## Importación de Librerías

# %%
# Aplicacion de modelo

# limpio la memoria
rm(list = ls()) # remove all objects
gc() # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  627623 33.6 1404614    75.1  994946  53.2
# Vcells 1149764  8.8 8388608    64.0 1769393  13.5

# %%
# Librerías necesarias
require("data.table")
require("rpart")
require("ggplot2")
require("ranger")
require("randomForest")
require("lightgbm")
# Out:
# Loading required package: data.table
# Loading required package: rpart
#
# Loading required package: ggplot2
#
# Loading required package: ranger
#
# Loading required package: randomForest
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: 'randomForest'
#
#
# The following object is masked from 'package:ranger':
#
#     importance
#
#
# The following object is masked from 'package:ggplot2':
#
#     margin
#
#
# Loading required package: lightgbm
#
# Loading required package: R6

# %%
# Aqui se debe poner la carpeta de la materia de SU computadora local
setwd("C:/Users/German/Desktop/dmeyf2023/German/Clase 1") # Establezco el Working Directory

# cargo el dataset
dataset <- fread("competencia_01_alternativo.csv")

# %%
# Poner sus semillas
semillas <- c(279511, 279523, 279541, 279551, 279571)

# %%
# Nos quedamos solo con el 202103
dataset <- dataset[foto_mes == 202103]

# %% [markdown]
# # Step 2: Primer Random Forest

# %%
# Importante que la clase sea factor
dataset[, clase_binaria1 := factor(ifelse(clase_ternaria == "BAJA+2", "evento", "noevento"))]

# %%
dataset$clase_ternaria <- NULL
in_training <- caret::createDataPartition(dataset$clase_binaria1,
                     p = 0.70, list = FALSE)

dtrain  <-  dataset[in_training, ]
dtest   <-  dataset[-in_training, ]

# ranger no soporta, como lo hacen otras librerías, los missing values
dtrain <-  na.roughfix(dtrain)
dtest <-  na.roughfix(dtest)

# Cantidad de variables que abren por cada hoja
n_variables <- round(sqrt(dim(dtrain)[2] - 1))

# %%
t0 <- Sys.time()
modelo_rf_1 <- ranger(clase_binaria1 ~ ., data = dtrain,
                  probability = TRUE,
                  num.trees = 100,
                  min.node.size=10,  # <---------
                  mtry = n_variables,
                  splitrule = "gini",
                  sample.fraction = 0.66,
                  importance = "impurity",
                  verbose = TRUE)
t1 <- Sys.time()
as.numeric(t1 - t0, units = "secs")
# Out:
# [1] 20.18665

# %% [markdown]
# # Step 3: Midiendo el primero RF

# %%
pred_train <- predict(modelo_rf_1, dtrain)
pred_test <- predict(modelo_rf_1, dtest)

# Ganancia en dtrain
print(sum((pred_train$predictions[, "evento"] >= 0.025) * ifelse(
                    dtrain$clase_binaria1 == "evento", 
                    273000, -7000) / 0.7))
# Ganancia en dtest
print(sum((pred_test$predictions[, "evento"] >= 0.025) * ifelse(
                    dtest$clase_binaria1 == "evento",
                    273000, -7000) / 0.3))
# Out:
# [1] 214500000
# [1] 60270000

# %% [markdown]
# Preguntas
# - ¿Qué paso en `train`?
# - ¿Se veía esa diferencia en los árboles?

# %% [markdown]
# # Step 4: Importancia de variables

# %%
importancia <- as.data.table(modelo_rf_1$variable.importance,
                    keep.rownames = TRUE)
colnames(importancia) <- c("variable", "importancia")
setorder(importancia, -importancia)
importancia
# Out:
#     variable                        importancia
# 1   mcuentas_saldo                  18.963521
# 2   mrentabilidad_annual            18.175787
# 3   mpasivos_margen                 18.057882
# 4   numero_de_cliente               17.041501
# 5   ctrx_quarter                    16.408563
# 6   mcuenta_corriente               15.824942
# 7   cliente_edad                    15.586140
# 8   cliente_antiguedad              15.406579
# 9   mactivos_margen                 15.217435
# 10  mrentabilidad                   15.051025
# 11  mcomisiones_otras               13.165062
# 12  Visa_fechaalta                  12.923936
# 13  Master_fechaalta                12.530604
# 14  mcomisiones                     12.239510
# 15  mcaja_ahorro                    11.911926
# 16  Master_Fvencimiento             10.470667
# 17  Visa_Fvencimiento                9.889253
# 18  Visa_mfinanciacion_limite        8.442838
# 19  Master_mfinanciacion_limite      8.136750
# 20  Visa_msaldopesos                 7.879508
# 21  mtarjeta_visa_consumo            7.830929
# 22  Visa_msaldototal                 7.813963
# 23  Master_mlimitecompra             7.677341
# 24  Visa_mlimitecompra               7.676401
# 25  cproductos                       7.378577
# 26  chomebanking_transacciones       7.150480
# 27  mtransferencias_recibidas        6.621059
# 28  Visa_mpagospesos                 6.603288
# 29  Visa_mconsumospesos              6.302227
# 30  Visa_mpagominimo                 6.214233
# ⋮   ⋮                               ⋮
# 125 mcheques_emitidos               0.2983687513
# 126 cinversion2                     0.2934631358
# 127 cseguro_auto                    0.2742617823
# 128 mforex_sell                     0.2257874711
# 129 mprestamos_prendarios           0.1969663104
# 130 cprestamos_hipotecarios         0.1716488631
# 131 mpagodeservicios                0.1301271161
# 132 ccheques_emitidos               0.1175978744
# 133 Master_delinquency              0.0966160032
# 134 cpagodeservicios                0.0907172836
# 135 mforex_buy                      0.0603327261
# 136 ccheques_emitidos_rechazados    0.0457213854
# 137 mcheques_emitidos_rechazados    0.0432109122
# 138 cforex_buy                      0.0417265157
# 139 ccuenta_corriente               0.0006818182
# 140 minversion1_dolares             0.0002561024
# 141 mplazo_fijo_pesos               0.0001098901
# 142 foto_mes                        0.0000000000
# 143 cliente_vip                     0.0000000000
# 144 mcuenta_corriente_adicional     0.0000000000
# 145 mpayroll2                       0.0000000000
# 146 cpayroll2_trx                   0.0000000000
# 147 ccheques_depositados_rechazados 0.0000000000
# 148 mcheques_depositados_rechazados 0.0000000000
# 149 Master_madelantopesos           0.0000000000
# 150 Master_madelantodolares         0.0000000000
# 151 Master_cadelantosefectivo       0.0000000000
# 152 Visa_madelantopesos             0.0000000000
# 153 Visa_madelantodolares           0.0000000000
# 154 Visa_cadelantosefectivo         0.0000000000

# %% [markdown]
# Preguntas
#  - ¿Qué significa que una variable sea más importante que otra?
#  - ¿Qué significa que una variable tenga 0 importancia?
#  - ¿Con el **RF** es suficiente como para descartarlas?
#  - ¿Qué una variable tenga algo de importancia es suficiente como para
#  - entender que da valor?

# %% [markdown]
# # Step 5: Un experimento con canaritos

# %%
dtrain$canarito <- runif(nrow(dtrain))

modelo_rf_2 <- ranger(clase_binaria1 ~ ., data = dtrain,
                  probability = TRUE,
                  num.trees = 150,
                  min.node.size = 10, # <-- probar con valores mas altos
                  mtry = n_variables,
                  splitrule = "gini",
                  importance = "impurity",
                  verbose = TRUE)

importancia2 <- as.data.table(modelo_rf_2$variable.importance,
                    keep.rownames = TRUE)
colnames(importancia2) <- c("variable", "importancia")
setorder(importancia2, -importancia)
importancia2
which(importancia2$variable == "canarito")

## Active learning o a llorar a la iglesia.
# Out:
# Growing trees.. Progress: 81%. Estimated remaining time: 7 seconds.
#     variable                        importancia
# 1   mcuentas_saldo                  30.496066
# 2   mrentabilidad_annual            28.045695
# 3   mpasivos_margen                 27.752238
# 4   numero_de_cliente               27.129295
# 5   canarito                        26.940222
# 6   ctrx_quarter                    25.472924
# 7   cliente_edad                    25.365977
# 8   mcuenta_corriente               25.049533
# 9   mrentabilidad                   23.892803
# 10  cliente_antiguedad              23.693734
# 11  mactivos_margen                 23.301986
# 12  mcaja_ahorro                    22.175165
# 13  Visa_fechaalta                  19.279574
# 14  Master_fechaalta                18.872922
# 15  mcomisiones_otras               18.456238
# 16  mcomisiones                     18.290543
# 17  Visa_Fvencimiento               16.512792
# 18  Master_Fvencimiento             15.736600
# 19  Visa_mfinanciacion_limite       13.620380
# 20  Visa_msaldopesos                13.429117
# 21  Visa_msaldototal                13.130086
# 22  Master_mfinanciacion_limite     13.122082
# 23  Visa_mlimitecompra              12.917203
# 24  Master_mlimitecompra            12.553009
# 25  mtarjeta_visa_consumo           12.229211
# 26  chomebanking_transacciones      12.128809
# 27  cproductos                      10.809870
# 28  mtransferencias_recibidas       10.289572
# 29  Visa_mpagospesos                 9.690998
# 30  Visa_mconsumospesos              9.261978
# ⋮   ⋮                               ⋮
# 126 cprestamos_prendarios           0.4857888204
# 127 cinversion2                     0.4334494538
# 128 mcheques_emitidos               0.3825956384
# 129 mprestamos_hipotecarios         0.3717348178
# 130 mpagodeservicios                0.2461175588
# 131 mforex_buy                      0.2232970252
# 132 mprestamos_prendarios           0.2012626897
# 133 ccheques_emitidos               0.1855917581
# 134 cforex_buy                      0.1846899975
# 135 Master_delinquency              0.1845143024
# 136 cpagodeservicios                0.1579954586
# 137 mcheques_emitidos_rechazados    0.1199819611
# 138 cprestamos_hipotecarios         0.1186799220
# 139 ccheques_emitidos_rechazados    0.0196550118
# 140 cliente_vip                     0.0014582948
# 141 ccuenta_corriente               0.0006833746
# 142 foto_mes                        0.0000000000
# 143 mcuenta_corriente_adicional     0.0000000000
# 144 mplazo_fijo_pesos               0.0000000000
# 145 minversion1_dolares             0.0000000000
# 146 mpayroll2                       0.0000000000
# 147 cpayroll2_trx                   0.0000000000
# 148 ccheques_depositados_rechazados 0.0000000000
# 149 mcheques_depositados_rechazados 0.0000000000
# 150 Master_madelantopesos           0.0000000000
# 151 Master_madelantodolares         0.0000000000
# 152 Master_cadelantosefectivo       0.0000000000
# 153 Visa_madelantopesos             0.0000000000
# 154 Visa_madelantodolares           0.0000000000
# 155 Visa_cadelantosefectivo         0.0000000000
# [1] 5

# %%
## ---------------------------
## Step 5.1: Hablando de los Extra Trees
## ---------------------------

modelo_rf_3 <- ranger(clase_binaria1 ~ ., data = dtrain,
                  probability = TRUE,
                  num.trees = 150,
                  min.node.size = 200, # <---------
                  mtry = n_variables,
                  splitrule = "extratrees", # <---------
                  num.random.splits = 10, # <---------
                  importance = "impurity",
                  verbose = TRUE)

importancia3 <- as.data.table(modelo_rf_3$variable.importance,
                    keep.rownames = TRUE)
colnames(importancia3) <- c("variable", "importancia")
setorder(importancia3, -importancia)
importancia3
which(importancia3$variable == "canarito")
# Out:
# Growing trees.. Progress: 76%. Estimated remaining time: 9 seconds.
#     variable                        importancia
# 1   ctrx_quarter                    7.521274
# 2   active_quarter                  5.433602
# 3   ccajas_consultas                5.200680
# 4   cproductos                      4.703825
# 5   cliente_edad                    3.474520
# 6   mcomisiones_mantenimiento       3.281442
# 7   mcuenta_corriente               3.218174
# 8   ccomisiones_mantenimiento       2.987467
# 9   ccomisiones_otras               2.979031
# 10  Master_Fvencimiento             2.915448
# 11  cliente_antiguedad              2.879371
# 12  ctarjeta_visa_transacciones     2.860454
# 13  ctarjeta_visa                   2.731623
# 14  Master_fechaalta                2.726909
# 15  ccajas_otras                    2.634968
# 16  Visa_fechaalta                  2.592728
# 17  Master_mlimitecompra            2.587598
# 18  Visa_mfinanciacion_limite       2.561700
# 19  numero_de_cliente               2.544038
# 20  canarito                        2.495795
# 21  ctarjeta_debito_transacciones   2.413517
# 22  Visa_mlimitecompra              2.297337
# 23  Master_mfinanciacion_limite     2.152330
# 24  cpayroll_trx                    2.042525
# 25  ctarjeta_debito                 1.986321
# 26  mactivos_margen                 1.960173
# 27  Visa_Fvencimiento               1.947676
# 28  chomebanking_transacciones      1.934496
# 29  mrentabilidad_annual            1.896125
# 30  mcomisiones                     1.851471
# ⋮   ⋮                               ⋮
# 126 ccajas_extracciones             0.26228376
# 127 mpagodeservicios                0.25579565
# 128 minversion2                     0.22592976
# 129 mprestamos_hipotecarios         0.20716005
# 130 Master_delinquency              0.16465569
# 131 ccaja_seguridad                 0.13658966
# 132 cforex_buy                      0.13357602
# 133 cprestamos_hipotecarios         0.07617443
# 134 mforex_buy                      0.07229290
# 135 mcheques_emitidos               0.06804966
# 136 mcheques_emitidos_rechazados    0.06604815
# 137 ccheques_emitidos               0.05946152
# 138 mprestamos_prendarios           0.03579782
# 139 ccheques_emitidos_rechazados    0.02488086
# 140 foto_mes                        0.00000000
# 141 cliente_vip                     0.00000000
# 142 ccuenta_corriente               0.00000000
# 143 mcuenta_corriente_adicional     0.00000000
# 144 mplazo_fijo_pesos               0.00000000
# 145 minversion1_dolares             0.00000000
# 146 mpayroll2                       0.00000000
# 147 cpayroll2_trx                   0.00000000
# 148 ccheques_depositados_rechazados 0.00000000
# 149 mcheques_depositados_rechazados 0.00000000
# 150 Master_madelantopesos           0.00000000
# 151 Master_madelantodolares         0.00000000
# 152 Master_cadelantosefectivo       0.00000000
# 153 Visa_madelantopesos             0.00000000
# 154 Visa_madelantodolares           0.00000000
# 155 Visa_cadelantosefectivo         0.00000000
# [1] 20

# %% [markdown]
# # Step 6: Boosting, la navaja suiza de los modelos - Conceptos

# %% [markdown]
#  Estos se construyen de forma serial.
# - Primero se parte de un modelo (que puede ser un valor constante) y se  complementa con un modelo que busca mejorar al anterior.
#
# Hay dos algoritmos muy conocidos de este tipo:
#
# - **Adaboost**: Que cada nuevo modelo va mejorando a los anteriores poniendo un peso mayor en los casos donde la clasificación es incorrecta
#
# - **Gradient Boosting**: Que cada nuevo modelo va mejorando los anteriores, tratando de corregir los residuos, buscando estos últimos con el gradiente de una función de perdida.
#
# Este último se empezó a hacer muy popular por la excelente pieza de tecnología que es su implementación **xgboost**, superado luego por el LightGBM.

# %% [markdown]
# # Step 7: LightGBM

# %%
# Cargamos todo para tener un código limpio
dataset <- fread("competencia_01_alternativo.csv")

# Nos quedamos solo con el 202103
dataset <- dataset[foto_mes == 202103]

clase_binaria <- ifelse(dataset$clase_ternaria == "BAJA+2", 1, 0)
dataset$clase_ternaria <- NULL

dtrain  <- lgb.Dataset(data = data.matrix(dataset), label = clase_binaria)

# %%
set.seed(semillas[1])
# LightGBM, al igual que XGB traen su implementación del CV
# Los parámetros los iremos viendo en profundidad la siguiente clase.
model_lgbm_cv <- lgb.cv(data = dtrain,
         eval = "auc",
         stratified = TRUE,
         nfold = 5,
         feature_pre_filter=FALSE,
         param = list(objective = "binary",
                       max_bin = 15,
                       min_data_in_leaf = 300,
                       learning_rate = 0.05
                       )
      )

# Mejor iteración
model_lgbm_cv$best_iter

# Una vez que elegimos los parámetros tenemos que entrenar con todos.
model_lgm <- lightgbm(data = dtrain,
            nrounds = model_lgbm_cv$best_iter,
            params = list(objective = "binary",
                            max_bin = 15,
                            min_data_in_leaf = 4000,
                            learning_rate = 0.05),
             verbose = -1)

# También tiene su importancia de variables
lgb.importance(model_lgm, percentage = TRUE)

## Bienvenido al mundo de los ensambles
# Out:
# Warning message in lgb.cv(data = dtrain, eval = "auc", stratified = TRUE, nfold = 5, :
# "lgb.cv: Found the following passed through '...': feature_pre_filter. These will be used, but in future releases of lightgbm, this warning will become an error. Add these to 'params' instead. See ?lgb.cv for documentation on how to call this function."
# [LightGBM] [Info] Number of positive: 780, number of negative: 129879
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049225 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1934
# [LightGBM] [Info] Number of data points in the train set: 130659, number of used features: 154
# [LightGBM] [Info] Number of positive: 775, number of negative: 129884
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039967 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1934
# [LightGBM] [Info] Number of data points in the train set: 130659, number of used features: 154
# [LightGBM] [Info] Number of positive: 782, number of negative: 129877
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036785 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1934
# [LightGBM] [Info] Number of data points in the train set: 130659, number of used features: 154
# [LightGBM] [Info] Number of positive: 759, number of negative: 129901
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.046739 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1934
# [LightGBM] [Info] Number of data points in the train set: 130660, number of used features: 154
# [LightGBM] [Info] Number of positive: 756, number of negative: 129903
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.073235 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1934
# [LightGBM] [Info] Number of data points in the train set: 130659, number of used features: 154
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005970 -> initscore=-5.115065
# [LightGBM] [Info] Start training from score -5.115065
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005931 -> initscore=-5.121534
# [LightGBM] [Info] Start training from score -5.121534
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005985 -> initscore=-5.112488
# [LightGBM] [Info] Start training from score -5.112488
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005809 -> initscore=-5.142526
# [LightGBM] [Info] Start training from score -5.142526
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005786 -> initscore=-5.146502
# [LightGBM] [Info] Start training from score -5.146502
# [1] "[1]:  valid's auc:0.873497+0.00549883"
# [1] "[2]:  valid's auc:0.879504+0.00687955"
# [1] "[3]:  valid's auc:0.885401+0.00830024"
# [1] "[4]:  valid's auc:0.888634+0.00685047"
# [1] "[5]:  valid's auc:0.889552+0.00654546"
# [1] "[6]:  valid's auc:0.890192+0.00622991"
# [1] "[7]:  valid's auc:0.890563+0.00655337"
# [1] "[8]:  valid's auc:0.89107+0.0064957"
# [1] "[9]:  valid's auc:0.891679+0.00594548"
# [1] "[10]:  valid's auc:0.892523+0.00526747"
# [1] "[11]:  valid's auc:0.892971+0.00453769"
# [1] "[12]:  valid's auc:0.893581+0.00389572"
# [1] "[13]:  valid's auc:0.894087+0.00336744"
# [1] "[14]:  valid's auc:0.894591+0.00377171"
# [1] "[15]:  valid's auc:0.894674+0.00367834"
# [1] "[16]:  valid's auc:0.894935+0.00355871"
# [1] "[17]:  valid's auc:0.895251+0.0037755"
# [1] "[18]:  valid's auc:0.89522+0.00329987"
# [1] "[19]:  valid's auc:0.896304+0.00282085"
# [1] "[20]:  valid's auc:0.896501+0.00266361"
# [1] "[21]:  valid's auc:0.896862+0.00288059"
# [1] "[22]:  valid's auc:0.897642+0.0033117"
# [1] "[23]:  valid's auc:0.897951+0.00300874"
# [1] "[24]:  valid's auc:0.898154+0.00322336"
# [1] "[25]:  valid's auc:0.898562+0.00301841"
# [1] "[26]:  valid's auc:0.898716+0.00277864"
# [1] "[27]:  valid's auc:0.899203+0.00213505"
# [1] "[28]:  valid's auc:0.899425+0.00208172"
# [1] "[29]:  valid's auc:0.89954+0.00204163"
# [1] "[30]:  valid's auc:0.899803+0.00172628"
# [1] "[31]:  valid's auc:0.899988+0.0014802"
# [1] "[32]:  valid's auc:0.899821+0.00149205"
# [1] "[33]:  valid's auc:0.900328+0.00191066"
# [1] "[34]:  valid's auc:0.900635+0.00214069"
# [1] "[35]:  valid's auc:0.900692+0.00230988"
# [1] "[36]:  valid's auc:0.900755+0.00251265"
# [1] "[37]:  valid's auc:0.901128+0.00293481"
# [1] "[38]:  valid's auc:0.901134+0.00297873"
# [1] "[39]:  valid's auc:0.901066+0.0029923"
# [1] "[40]:  valid's auc:0.901003+0.00320392"
# [1] "[41]:  valid's auc:0.900956+0.00336798"
# [1] "[42]:  valid's auc:0.901022+0.00333892"
# [1] "[43]:  valid's auc:0.901174+0.00358106"
# [1] "[44]:  valid's auc:0.90107+0.00386996"
# [1] "[45]:  valid's auc:0.900868+0.00390053"
# [1] "[46]:  valid's auc:0.901011+0.00400606"
# [1] "[47]:  valid's auc:0.901033+0.00411485"
# [1] "[48]:  valid's auc:0.901054+0.00414764"
# [1] "[49]:  valid's auc:0.901014+0.00425321"
# [1] "[50]:  valid's auc:0.900996+0.00400973"
# [1] "[51]:  valid's auc:0.900837+0.00416993"
# [1] "[52]:  valid's auc:0.900774+0.00424548"
# [1] "[53]:  valid's auc:0.900962+0.00374411"
# [1] "[54]:  valid's auc:0.901025+0.00382604"
# [1] "[55]:  valid's auc:0.901188+0.00372805"
# [1] "[56]:  valid's auc:0.901061+0.00386223"
# [1] "[57]:  valid's auc:0.901288+0.00399105"
# [1] "[58]:  valid's auc:0.901487+0.00366586"
# [1] "[59]:  valid's auc:0.901688+0.0036236"
# [1] "[60]:  valid's auc:0.901878+0.0037211"
# [1] "[61]:  valid's auc:0.901991+0.00356559"
# [1] "[62]:  valid's auc:0.901959+0.00365118"
# [1] "[63]:  valid's auc:0.90193+0.00343116"
# [1] "[64]:  valid's auc:0.901989+0.00320592"
# [1] "[65]:  valid's auc:0.902078+0.0031268"
# [1] "[66]:  valid's auc:0.90173+0.00314175"
# [1] "[67]:  valid's auc:0.90176+0.00302541"
# [1] "[68]:  valid's auc:0.901981+0.00289163"
# [1] "[69]:  valid's auc:0.901986+0.00300048"
# [1] "[70]:  valid's auc:0.901912+0.00312069"
# [1] "[71]:  valid's auc:0.90196+0.00302708"
# [1] "[72]:  valid's auc:0.902025+0.00312576"
# [1] "[73]:  valid's auc:0.901998+0.00318604"
# [1] "[74]:  valid's auc:0.902017+0.0032664"
# [1] "[75]:  valid's auc:0.901936+0.00327557"
# [1] "[76]:  valid's auc:0.902044+0.0031566"
# [1] "[77]:  valid's auc:0.901865+0.00320708"
# [1] "[78]:  valid's auc:0.901814+0.00317538"
# [1] "[79]:  valid's auc:0.90181+0.00336378"
# [1] "[80]:  valid's auc:0.901785+0.00346885"
# [1] "[81]:  valid's auc:0.901808+0.00356813"
# [1] "[82]:  valid's auc:0.901583+0.00358037"
# [1] "[83]:  valid's auc:0.901556+0.00346196"
# [1] "[84]:  valid's auc:0.901491+0.00363271"
# [1] "[85]:  valid's auc:0.901293+0.0036116"
# [1] "[86]:  valid's auc:0.901494+0.00335092"
# [1] "[87]:  valid's auc:0.901562+0.00348592"
# [1] "[88]:  valid's auc:0.901601+0.00339223"
# [1] "[89]:  valid's auc:0.901487+0.00349639"
# [1] "[90]:  valid's auc:0.901361+0.00356147"
# [1] "[91]:  valid's auc:0.901166+0.00356111"
# [1] "[92]:  valid's auc:0.901325+0.00345864"
# [1] "[93]:  valid's auc:0.901191+0.00354596"
# [1] "[94]:  valid's auc:0.900999+0.00365443"
# [1] "[95]:  valid's auc:0.901094+0.00373984"
# [1] "[96]:  valid's auc:0.901144+0.00380019"
# [1] "[97]:  valid's auc:0.901149+0.00372241"
# [1] "[98]:  valid's auc:0.901072+0.00383356"
# [1] "[99]:  valid's auc:0.901046+0.00400115"
# [1] "[100]:  valid's auc:0.900985+0.00413361"
# [1] 65
#    Feature                           Gain         Cover        Frequency
# 1  ctrx_quarter                      0.405383000  0.1156625178 0.0685358255
# 2  cpayroll_trx                      0.079414003  0.0746348214 0.0259605400
# 3  mpasivos_margen                   0.046114690  0.0230858603 0.0249221184
# 4  mprestamos_personales             0.044083420  0.0313805168 0.0181723780
# 5  mpayroll                          0.041305883  0.0576951109 0.0254413292
# 6  mcuentas_saldo                    0.038841315  0.0259066799 0.0295950156
# 7  mcaja_ahorro                      0.035607134  0.0057356225 0.0103842160
# 8  mrentabilidad_annual              0.028864194  0.0292648476 0.0446521288
# 9  mtarjeta_visa_consumo             0.023057361  0.0409682346 0.0306334372
# 10 mactivos_margen                   0.019888719  0.0303983522 0.0290758048
# 11 cproductos                        0.018106878  0.0210339355 0.0223260644
# 12 mcomisiones_mantenimiento         0.013403901  0.0211314754 0.0212876428
# 13 Visa_mpagominimo                  0.013251530  0.0117228107 0.0202492212
# 14 Visa_mfinanciacion_limite         0.010638465  0.0048394569 0.0088265836
# 15 mcuenta_corriente                 0.010129502  0.0088780380 0.0119418484
# 16 Master_Fvencimiento               0.009114905  0.0157215281 0.0285565940
# 17 cliente_edad                      0.007203198  0.0138298423 0.0244029076
# 18 Visa_msaldototal                  0.007107348  0.0050884966 0.0103842160
# 19 Visa_Fvencimiento                 0.007101115  0.0095167295 0.0207684320
# 20 mrentabilidad                     0.006996046  0.0118433312 0.0186915888
# 21 chomebanking_transacciones        0.006409215  0.0237895446 0.0306334372
# 22 cdescubierto_preacordado          0.006185881  0.0095493638 0.0057113188
# 23 Visa_status                       0.006070492  0.0020544218 0.0036344756
# 24 mtransferencias_emitidas          0.005981812  0.0336378431 0.0420560748
# 25 Visa_mpagospesos                  0.005659843  0.0121952096 0.0129802700
# 26 Visa_msaldopesos                  0.005594820  0.0102866840 0.0145379024
# 27 mautoservicio                     0.005408071  0.0407000033 0.0280373832
# 28 ctarjeta_visa                     0.005003524  0.0003375791 0.0005192108
# 29 Master_mpagospesos                0.004885490  0.0047387087 0.0046728972
# 30 Visa_cconsumos                    0.004631987  0.0109261594 0.0218068536
# ⋮  ⋮                                 ⋮            ⋮            ⋮
# 59 ccallcenter_transacciones         8.696434e-04 0.0187385019 0.0114226376
# 60 mplazo_fijo_dolares               8.060619e-04 0.0070807274 0.0015576324
# 61 Master_mlimitecompra              7.798806e-04 0.0008897201 0.0025960540
# 62 ctransferencias_recibidas         7.774970e-04 0.0023298535 0.0072689512
# 63 Visa_mconsumosdolares             6.937790e-04 0.0018375953 0.0041536864
# 64 Visa_fultimo_cierre               6.740119e-04 0.0019966730 0.0020768432
# 65 mextraccion_autoservicio          6.556763e-04 0.0020665290 0.0041536864
# 66 Visa_mlimitecompra                6.494077e-04 0.0024130506 0.0031152648
# 67 cmobile_app_trx                   6.384419e-04 0.0009514755 0.0015576324
# 68 ctransferencias_emitidas          6.267707e-04 0.0026466733 0.0062305296
# 69 Master_fultimo_cierre             6.163869e-04 0.0012602383 0.0015576324
# 70 mtarjeta_master_consumo           5.636923e-04 0.0017720800 0.0046728972
# 71 mcomisiones                       5.012418e-04 0.0026941875 0.0041536864
# 72 ccajas_transacciones              4.268712e-04 0.0017795417 0.0010384216
# 73 Visa_mpagosdolares                4.165119e-04 0.0005864592 0.0015576324
# 74 Master_cconsumos                  4.136900e-04 0.0002830822 0.0010384216
# 75 Visa_mpagado                      2.885466e-04 0.0001801709 0.0005192108
# 76 Visa_delinquency                  2.586480e-04 0.0001654652 0.0005192108
# 77 Master_msaldototal                2.384590e-04 0.0010782963 0.0025960540
# 78 catm_trx                          2.206437e-04 0.0049878791 0.0051921080
# 79 ctarjeta_visa_debitos_automaticos 8.212780e-05 0.0001178057 0.0005192108
# 80 matm_other                        6.767494e-05 0.0014561893 0.0020768432
# 81 cextraccion_autoservicio          6.600230e-05 0.0039833293 0.0036344756
# 82 Master_delinquency                5.172303e-05 0.0001508610 0.0005192108
# 83 Master_msaldodolares              4.160028e-05 0.0003752799 0.0005192108
# 84 catm_trx_other                    3.998777e-05 0.0004041833 0.0010384216
# 85 Master_msaldopesos                1.261189e-05 0.0003327450 0.0010384216
# 86 Visa_msaldodolares                1.228498e-05 0.0017945378 0.0020768432
# 87 matm                              1.075932e-05 0.0004056785 0.0015576324
# 88 tcallcenter                       5.238773e-11 0.0031465964 0.0036344756
